# %%
import pandas as pd

# %%
df = pd.read_excel('Gold Price Prediction.xlsx')
df
# Out:
#                     Date   Price 2 Days Prior    Price 1 Day Prior  \
# 0    2024-07-08 00:00:00              2405.87  2384-09-01 00:00:00
# 1    2024-06-08 00:00:00              2442.74              2405.87
# 2    2024-05-08 00:00:00              2447.17              2442.74
# 3    2024-02-08 00:00:00              2447.23              2447.17
# 4    2024-01-08 00:00:00  2411-09-01 00:00:00              2447.23
# ..                   ...                  ...                  ...
# 671  2022-07-01 00:00:00              1810.28              1791.61
# 672  2022-06-01 00:00:00              1813.88              1810.28
# 673  2022-05-01 00:00:00              1804.27              1813.88
# 674  2022-04-01 00:00:00              1815.73              1804.27
# 675  2022-03-01 00:00:00              1804.64              1829.05
#
#              Price Today       Price Tomorrow Price Change Tomorrow  \
# 0                2385.83                  NaN                   NaN
# ...

# %%
df.dtypes
# Out:
# Date                                       object
# Price 2 Days Prior                         object
# Price 1 Day Prior                          object
# Price Today                                object
# Price Tomorrow                             object
# Price Change Tomorrow                      object
# Price Change Ten                           object
# Std Dev 10                                float64
# Twenty Moving Average                      object
# Fifty Day Moving Average                   object
# 200 Day Moving Average                    float64
# Monthly Inflation Rate                     object
# EFFR Rate                                  object
# Volume                                      int64
# Treasury Par Yield Month                   object
# Treasury Par Yield Two Year                object
# Treasury Par Yield Curve Rates (10 Yr)     object
# DXY                                       float64
# SP Open                                    object
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 676 entries, 0 to 675
# Data columns (total 21 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Date                                    676 non-null    object
#  1   Price 2 Days Prior                      676 non-null    object
#  2   Price 1 Day Prior                       676 non-null    object
#  3   Price Today                             676 non-null    object
#  4   Price Tomorrow                          675 non-null    object
#  5   Price Change Tomorrow                   675 non-null    object
#  6   Price Change Ten                        666 non-null    object
#  7   Std Dev 10                              667 non-null    float64
#  8   Twenty Moving Average                   676 non-null    object
#  9   Fifty Day Moving Average                676 non-null    object
# ...

# %%
df.shape
# Out:
# (676, 21)

# %%
DatosFaltantes=df.isna().sum()
DatosFaltantes
# Out:
# Date                                       0
# Price 2 Days Prior                         0
# Price 1 Day Prior                          0
# Price Today                                0
# Price Tomorrow                             1
# Price Change Tomorrow                      1
# Price Change Ten                          10
# Std Dev 10                                 9
# Twenty Moving Average                      0
# Fifty Day Moving Average                   0
# 200 Day Moving Average                     0
# Monthly Inflation Rate                     0
# EFFR Rate                                  0
# Volume                                     0
# Treasury Par Yield Month                   0
# Treasury Par Yield Two Year                0
# Treasury Par Yield Curve Rates (10 Yr)     0
# DXY                                        0
# SP Open                                    0
# VIX                                        0
# Crude                                      0
# ...

# %%
for column in df.columns:
  if df[column].dtype == 'object' and column != 'Date':
    df[column] = df[column].astype('float64')

df.dtypes
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-d8aeb516fe96> in <cell line: 1>()
#       1 for column in df.columns:
#       2   if df[column].dtype == 'object' and column != 'Date':
# ----> 3     df[column] = df[column].astype('float64')
#       4
#       5 df.dtypes
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6532         else:
#    6533             # else, only a single dtype is given
# -> 6534             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536             return res.__finalize__(self, method="astype")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     412             copy = False
#     413
# ...

# %%
# prompt: me sale este error TypeError                                 Traceback (most recent call last)
# <ipython-input-67-d8aeb516fe96> in <cell line: 1>()
#       1 for column in df.columns:
#       2   if df[column].dtype == 'object' and column != 'Date':
# ----> 3     df[column] = df[column].astype('float64')
#       4
#       5 df.dtypes
# 6 frames
# /usr/local/lib/python3.10/dist-packages/pandas/core/dtypes/astyp

for column in df.columns:
  if df[column].dtype == 'object' and column != 'Date':
    try:
      df[column] = df[column].str.replace(',', '.').astype('float64') # Reemplaza comas por puntos y convierte a float64
    except:
      print(f"Error converting column {column}") # Imprime un mensaje de error si la conversión falla
df.dtypes
# Out:
# Date                                       object
# Price 2 Days Prior                        float64
# Price 1 Day Prior                         float64
# Price Today                               float64
# Price Tomorrow                            float64
# Price Change Tomorrow                     float64
# Price Change Ten                          float64
# Std Dev 10                                float64
# Twenty Moving Average                     float64
# Fifty Day Moving Average                  float64
# 200 Day Moving Average                    float64
# Monthly Inflation Rate                    float64
# EFFR Rate                                 float64
# Volume                                      int64
# Treasury Par Yield Month                  float64
# Treasury Par Yield Two Year               float64
# Treasury Par Yield Curve Rates (10 Yr)    float64
# DXY                                       float64
# SP Open                                   float64
# ...

# %%
for col in df.columns:
    if df[col].dtype == 'object' and col != 'Date':
        df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 676 entries, 0 to 675
# Data columns (total 21 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Date                                    676 non-null    object
#  1   Price 2 Days Prior                      596 non-null    float64
#  2   Price 1 Day Prior                       595 non-null    float64
#  3   Price Today                             595 non-null    float64
#  4   Price Tomorrow                          594 non-null    float64
#  5   Price Change Tomorrow                   605 non-null    float64
#  6   Price Change Ten                        635 non-null    float64
#  7   Std Dev 10                              667 non-null    float64
#  8   Twenty Moving Average                   672 non-null    float64
#  9   Fifty Day Moving Average                672 non-null    float64
# ...

# %%
ListaValNum = ["Price Tomorrow","Price Change Tomorrow","Price Change Ten","Std Dev 10"]

# %%
for col in ListaValNum:
 df[col] = df[col].fillna(df[col].mean())

# %%
DatosFaltantes=df.isna().sum()
DatosFaltantes
# Out:
# Date                                        0
# Price 2 Days Prior                         87
# Price 1 Day Prior                          88
# Price Today                                88
# Price Tomorrow                              0
# Price Change Tomorrow                       0
# Price Change Ten                            0
# Std Dev 10                                  0
# Twenty Moving Average                     650
# Fifty Day Moving Average                  669
# 200 Day Moving Average                      0
# Monthly Inflation Rate                    676
# EFFR Rate                                  86
# Volume                                      0
# Treasury Par Yield Month                   76
# Treasury Par Yield Two Year               154
# Treasury Par Yield Curve Rates (10 Yr)    127
# DXY                                         0
# SP Open                                   138
# VIX                                       143
# ...
