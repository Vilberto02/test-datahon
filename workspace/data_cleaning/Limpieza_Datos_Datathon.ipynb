# %%
import pandas as pd

# %%
df_precios = pd.read_csv('Gold Price Prediction.csv')
df_precios.head(100)
# Out:
#        Date  Price 2 Days Prior  Price 1 Day Prior  Price Today  \
# 0    8/7/24             2405.87            2384.90      2385.83
# 1    8/6/24             2442.74            2405.87      2384.90
# 2    8/5/24             2447.17            2442.74      2405.87
# 3    8/2/24             2447.23            2447.17      2442.74
# 4    8/1/24             2411.09            2447.23      2447.17
# ..      ...                 ...                ...          ...
# 95  3/25/24             2181.81            2165.64      2173.10
# 96  3/22/24             2204.04            2181.81      2165.64
# 97  3/21/24             2157.16            2204.04      2181.81
# 98  3/20/24             2161.98            2157.16      2204.04
# 99  3/19/24             2156.08            2161.98      2157.16
#
#     Price Tomorrow  Price Change Tomorrow  Price Change Ten  Std Dev 10  \
# 0              NaN                    NaN               NaN   30.155078
# ...

# %%
df_precios.dtypes
# Out:
# Date                                       object
# Price 2 Days Prior                        float64
# Price 1 Day Prior                         float64
# Price Today                               float64
# Price Tomorrow                            float64
# Price Change Tomorrow                     float64
# Price Change Ten                          float64
# Std Dev 10                                float64
# Twenty Moving Average                     float64
# Fifty Day Moving Average                  float64
# 200 Day Moving Average                    float64
# Monthly Inflation Rate                    float64
# EFFR Rate                                 float64
# Volume                                      int64
# Treasury Par Yield Month                  float64
# Treasury Par Yield Two Year               float64
# Treasury Par Yield Curve Rates (10 Yr)    float64
# DXY                                       float64
# SP Open                                   float64
# ...

# %%
DatosFaltantes=df_precios.isna().sum()
DatosFaltantes
# Out:
# Date                                       0
# Price 2 Days Prior                         0
# Price 1 Day Prior                          0
# Price Today                                0
# Price Tomorrow                             1
# Price Change Tomorrow                      1
# Price Change Ten                          10
# Std Dev 10                                 9
# Twenty Moving Average                      0
# Fifty Day Moving Average                   0
# 200 Day Moving Average                     0
# Monthly Inflation Rate                     0
# EFFR Rate                                  0
# Volume                                     0
# Treasury Par Yield Month                   0
# Treasury Par Yield Two Year                0
# Treasury Par Yield Curve Rates (10 Yr)     0
# DXY                                        0
# SP Open                                    0
# VIX                                        0
# Crude                                      0
# ...

# %%
ListaValNum = ["Price Tomorrow","Price Change Tomorrow","Price Change Ten","Std Dev 10"]
for col in ListaValNum:
 df_precios[col] = df_precios[col].fillna(df_precios[col].mean())

# %%
DatosFaltantes=df_precios.isna().sum()
DatosFaltantes
# Out:
# Date                                      0
# Price 2 Days Prior                        0
# Price 1 Day Prior                         0
# Price Today                               0
# Price Tomorrow                            0
# Price Change Tomorrow                     0
# Price Change Ten                          0
# Std Dev 10                                0
# Twenty Moving Average                     0
# Fifty Day Moving Average                  0
# 200 Day Moving Average                    0
# Monthly Inflation Rate                    0
# EFFR Rate                                 0
# Volume                                    0
# Treasury Par Yield Month                  0
# Treasury Par Yield Two Year               0
# Treasury Par Yield Curve Rates (10 Yr)    0
# DXY                                       0
# SP Open                                   0
# VIX                                       0
# Crude                                     0
# dtype: int64

# %% [markdown]
# Modelo predictivo

# %%
from google.colab import files


df_precios.to_csv('datos.csv', index=False)

# Descargar el archivo
files.download('datos.csv')
